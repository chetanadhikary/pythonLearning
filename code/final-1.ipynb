# %% [markdown]
# # Multiple Choice Questions

# %% [markdown]
# <html>
#     <b> 1.The byte code generated by python has a file extension of </b>
#     <ol>
#         <li>.pyc</li>
#         <li> .py</li>
#         <li> .c</li>
#         <li> .exe</li>
#     </ol>

# %% [markdown]
# <html>
#     <b> 2. If L1 and L2 are two lists. For the two python codes </b>
#     <ol>
#         <li> L2= L1 </li>
#         <li> L2= L1[:] </li>
#     </ol>
#     <ol>
#         <li> Both statements (1) and (2) are same. </li>
#         <li> Statement (1) is a multiple reference to same object and (2) is a copy </li>
#         <li> Statement (1) is a copy to same object and (2) is a multiple reference</li>
#         <li> Results in error</li>
#     </ol>

# %% [markdown]
# <html>
#     <b> 3. Which one of the following statements is True with respect to functions in Python3 </b>
#     <ol>
#         <li> The local variable used in a function occupy space in the computer’s memory when that function is written</li>
#         <li> The local variable used in a function occupy space in the computer’s memory only when that function is executing</li>
#         <li> The local variable used in a function never occupies space in the computer’s memory</li>
#         <li> The local variable used in a function occupy space depending upon the underlying OS on which the python program is executed</li>
#     </ol>

# %% [markdown]
# <html>
#     <b> 4. A module can contain</b>
#     <ul>
#         <li> executable statements as well as function definitions.</li>
#         <li> only executable statements</li>
#         <li> only function definitions.</li>
#         <li> neither contain executable statements nor function definitions.</li>
#     </ul>

# %% [markdown]
# <html>
#     <b> 5.Which of the following in-built functions can be called with a tuple object </b>
#     <ol>
#         <li> count,index,del </li>
#         <li> count,index, append,del</li>
#         <li> count,index, append,add</li>
#         <li> count,index,len</li>
#     </ol>

# %% [markdown]
# # Programming Questions

# %% [markdown]
# <html>
# <b>1. Write a progam to create a list of cars. Each car has attributes such as ModelName ,YearOfDesign, Category. </b>
#     <ol>
#         <li> Create a function to create a car along with the attributes for each car </li>
#         <li> Create a function to search for the car with ModelName being the criteria for search </li>

# %% [markdown]
# <html>
#     <b>2. Create a class Company and create cars to that class.</b>
#         <ol>
#             <li> Company class has attributes company name and a list of cars.</li>
#             <li> Modify the same functions to create and search for the car in Program 1 .</li>
#             <li> If python's in-built function print is used for the company object , the output should display company name and the all the cars in the company</li>

# %% [markdown]
# <html>
# <b>3.a Which column contains the highest number of row-wise minimum values in the numpy array arr ?</b>
#     <p> arr = np.random.rand(150).reshape(15, 10)</p>

# %% [markdown]
# <html>
#     <b>3.b. Create a new array containing the minimum and maximum of each row</b>
#     <p> arr = np.random.rand(150).reshape(15, 10)</p>

# %% [markdown]
# <html>
#     <b> 4. A dataset containing the match details of IPL is given . </b>
#     <p> Analyze the dataset to find the <b>team</b> which won maximum number of matches after winning the toss in <b>each season</b></p>
